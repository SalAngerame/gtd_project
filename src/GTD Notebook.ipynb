# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import statsmodels.formula.api as smf
import statsmodels.api as sm
import joblib
from math import ceil
from scipy import stats
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score, accuracy_score, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
import os
os.environ['OMP_NUM_THREADS'] = '1'

gtd_df = pd.read_csv(r"C:\Coding\CSV\Final Project Canadits\GTD.csv", encoding='latin-1')
# Out:
# C:\Users\torie\AppData\Local\Temp\ipykernel_37960\3640069162.py:25: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   gtd_df = pd.read_csv(r"C:\Coding\CSV\Final Project Canadits\GTD.csv", encoding='latin-1')

# %%
gtd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199793 entries, 0 to 199792
# Data columns (total 75 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   eventid                       199793 non-null  int64
#  1   extended                      199793 non-null  int64
#  2   country                       199793 non-null  int64
#  3   country_txt                   199793 non-null  object
#  4   region                        199793 non-null  int64
#  5   region_txt                    199793 non-null  object
#  6   provstate                     199793 non-null  object
#  7   city                          199366 non-null  object
#  8   latitude                      195410 non-null  float64
#  9   longitude                     195409 non-null  float64
#  10  specificity                   199792 non-null  float64
#  11  crit1                         199793 non-null  int64
#  12  crit2                         199793 non-null  int64
#  13  crit3                         199793 non-null  int64
#  14  doubtterr                     199793 non-null  int64
#  15  multiple                      199792 non-null  float64
#  16  success                       199793 non-null  int64
#  17  suicide                       199793 non-null  int64
#  18  attacktype1                   199793 non-null  int64
#  19  attacktype2                   8415 non-null    float64
#  20  attacktype3                   656 non-null     float64
#  21  targtype1                     199793 non-null  int64
#  22  targtype1_txt                 199793 non-null  object
#  23  targsubtype1                  188587 non-null  float64
#  24  targsubtype1_txt              188587 non-null  object
#  25  corp1                         163536 non-null  object
#  26  natlty1                       197809 non-null  float64
#  27  natlty1_txt                   197809 non-null  object
#  28  targtype2                     14395 non-null   float64
#  29  targtype2_txt                 14395 non-null   object
#  30  targsubtype2                  13904 non-null   float64
#  31  targsubtype2_txt              13904 non-null   object
#  32  corp2                         13404 non-null   object
#  33  target2                       14294 non-null   object
#  34  natlty2                       14094 non-null   float64
#  35  natlty2_txt                   14094 non-null   object
#  36  targtype3                     1616 non-null    float64
#  37  targtype3_txt                 1616 non-null    object
#  38  targsubtype3                  1531 non-null    float64
#  39  targsubtype3_txt              1531 non-null    object
#  40  corp3                         1471 non-null    object
#  41  target3                       1615 non-null    object
#  42  natlty3                       1587 non-null    float64
#  43  natlty3_txt                   1587 non-null    object
#  44  gname                         199793 non-null  object
#  45  gname2                        2557 non-null    object
#  46  gname3                        414 non-null     object
#  47  nperps                        136254 non-null  float64
#  48  nperpcap                      139362 non-null  float64
#  49  claimed                       142736 non-null  float64
#  50  compclaim                     4940 non-null    float64
#  51  weaptype1                     199793 non-null  int64
#  52  weapsubtype1                  175887 non-null  float64
#  53  weaptype2                     15867 non-null   float64
#  54  weapsubtype2                  13817 non-null   float64
#  55  weaptype3                     2303 non-null    float64
#  56  weapsubtype3                  2072 non-null    float64
#  57  weaptype4                     62 non-null      float64
#  58  weapsubtype4                  61 non-null      float64
#  59  all killed                    188471 non-null  float64
#  60  all U.S citizens  killed      144079 non-null  float64
#  61  perpetrators killed           140319 non-null  float64
#  62  all wounded                   182352 non-null  float64
#  63  all U.S citizens wounded      143843 non-null  float64
#  64  perpetrators wounded          137674 non-null  float64
#  65  property                      199793 non-null  int64
#  66  propextent                    68760 non-null   float64
#  67  propvalue                     45597 non-null   float64
#  68  all hostages                  15847 non-null   float64
#  69  U.S citizen hostages          15792 non-null   float64
#  70  divert                        289 non-null     object
#  71  ransomamt                     1244 non-null    float64
#  72  hostkidoutcome                13634 non-null   float64
#  73  any nationality similarities  199793 non-null  int64
#  74  related                       29976 non-null   object
# dtypes: float64(37), int64(15), object(23)
# memory usage: 114.3+ MB

# %%
gtd_df.describe()
# Out:
#             eventid       extended        country         region  \
# count  1.997930e+05  199793.000000  199793.000000  199793.000000
# mean   2.006294e+11       0.052775     125.859760       7.342835
# std    1.218108e+09       0.223584     104.585253       2.870762
# min    1.980010e+11       0.000000       4.000000       1.000000
# 25%    1.995072e+11       0.000000      69.000000       6.000000
# 50%    2.012073e+11       0.000000      97.000000       6.000000
# 75%    2.016023e+11       0.000000     160.000000      10.000000
# max    2.020123e+11       1.000000    1004.000000      12.000000
#
#             latitude      longitude    specificity          crit1  \
# count  195410.000000  195409.000000  199792.000000  199793.000000
# mean       22.882196      32.946622       1.481596       0.987867
# std        17.780072      55.023366       0.990539       0.109478
# min       -53.154613    -176.176447       1.000000       0.000000
# 25%        11.020013      13.140468       1.000000       1.000000
# 50%        31.074160      44.121801       1.000000       1.000000
# 75%        34.339532      69.147011       1.000000       1.000000
# max        74.633553     179.366667       5.000000       1.000000
#
#                crit2          crit3  ...  all U.S citizens wounded  \
# count  199793.000000  199793.000000  ...             143843.000000
# mean        0.993518       0.863874  ...                  0.031173
# std         0.080248       0.342923  ...                  2.762092
# min         0.000000       0.000000  ...                  0.000000
# 25%         1.000000       1.000000  ...                  0.000000
# 50%         1.000000       1.000000  ...                  0.000000
# 75%         1.000000       1.000000  ...                  0.000000
# max         1.000000       1.000000  ...                751.000000
#
#        perpetrators wounded       property    propextent     propvalue  \
# count         137674.000000  199793.000000  68760.000000  4.559700e+04
# mean               0.138625      -0.776934      3.286184  1.774392e+05
# std                1.566974       3.349550      0.479309  1.440339e+07
# min                0.000000      -9.000000      1.000000 -9.900000e+01
# 25%                0.000000       0.000000      3.000000 -9.900000e+01
# 50%                0.000000       0.000000      3.000000 -9.900000e+01
# 75%                0.000000       1.000000      4.000000 -9.900000e+01
# max              200.000000       1.000000      7.000000  2.700000e+09
#
#        all hostages  U.S citizen hostages     ransomamt  hostkidoutcome  \
# count  15847.000000          15792.000000  1.244000e+03    13634.000000
# mean       3.142614             -0.325038  2.302186e+06        4.769180
# std      184.226481              6.257315  1.321085e+07        2.020735
# min      -99.000000            -99.000000 -9.900000e+01        1.000000
# 25%        1.000000              0.000000 -9.900000e+01        2.000000
# 50%        2.000000              0.000000  1.028591e+04        4.000000
# 75%        4.000000              0.000000  3.018338e+05        7.000000
# max    17000.000000             86.000000  2.000000e+08        7.000000
#
#        any nationality similarities
# count                 199793.000000
# mean                      -3.952381
# std                        4.676415
# min                       -9.000000
# 25%                       -9.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        1.000000
#
# [8 rows x 52 columns]
